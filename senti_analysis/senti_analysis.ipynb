# %% [markdown]
# # Sentimental Analysis Model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "fiendfrye/mental-status-classifier-lama-3.1-8b-fine-tuned"

# Load model without device_map and without 4-bit quantization
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,  # Use float16 to save memory
    # Explicitly avoid device_map and quantization
    load_in_4bit=False,
    load_in_8bit=False
)

# Manually move to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

tokenizer = AutoTokenizer.from_pretrained(model_name)

# Text to classify
text = "I'm trapped in a storm of emotions that I can't control, and it feels like no one understands the chaos inside me"

# Create complete prompt
prompt = f"""Classify the text into Normal, Depression, Anxiety, and return the answer as the corresponding mental health disorder label.
text: {text}
label: """

# Generate directly with the model
inputs = tokenizer(prompt, return_tensors="pt").to(device)
with torch.no_grad():
    output = model.generate(
        **inputs,
        max_new_tokens=2,
        do_sample=True,
        temperature=0.1
    )

result = tokenizer.decode(output[0], skip_special_tokens=True)
print(result.split("label: ")[-1].strip())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 7
#       4 model_name = "fiendfrye/mental-status-classifier-lama-3.1-8b-fine-tuned"
#       6 # Load model without device_map and without 4-bit quantization
# ----> 7 model = AutoModelForCausalLM.from_pretrained(
#       8     model_name,
#       9     torch_dtype=torch.float16,  # Use float16 to save memory
#      10     # Explicitly avoid device_map and quantization
#      11     load_in_4bit=False,
#      12     load_in_8bit=False
#      13 )
#      15 # Manually move to GPU if available
#      16 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:571, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569     if model_class.config_class == config.sub_configs.get("text_config", None):
#     570         config = config.get_text_config()
# --> 571     return model_class.from_pretrained(
#     572         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573     )
#     574 raise ValueError(
#     575     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     576     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     577 )
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/modeling_utils.py:279, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     277 old_dtype = torch.get_default_dtype()
#     278 try:
# --> 279     return func(*args, **kwargs)
#     280 finally:
#     281     torch.set_default_dtype(old_dtype)
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/modeling_utils.py:4228, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4225     hf_quantizer = None
#    4227 if hf_quantizer is not None:
# -> 4228     hf_quantizer.validate_environment(
#    4229         torch_dtype=torch_dtype,
#    4230         from_tf=from_tf,
#    4231         from_flax=from_flax,
#    4232         device_map=device_map,
#    4233         weights_only=weights_only,
#    4234     )
#    4235     torch_dtype = hf_quantizer.update_torch_dtype(torch_dtype)
#    4236     device_map = hf_quantizer.update_device_map(device_map)
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/quantizers/quantizer_bnb_4bit.py:72, in Bnb4BitHfQuantizer.validate_environment(self, *args, **kwargs)
#      70 def validate_environment(self, *args, **kwargs):
#      71     if not is_accelerate_available():
# ---> 72         raise ImportError(
#      73             f"Using `bitsandbytes` 4-bit quantization requires Accelerate: `pip install 'accelerate>={ACCELERATE_MIN_VERSION}'`"
#      74         )
#      75     if not is_bitsandbytes_available():
#      76         raise ImportError(
#      77             "Using `bitsandbytes` 4-bit quantization requires the latest version of bitsandbytes: `pip install -U bitsandbytes`"
#      78         )
#
# ImportError: Using `bitsandbytes` 4-bit quantization requires Accelerate: `pip install 'accelerate>=0.26.0'`

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "fiendfrye/mental-status-classifier-lama-3.1-8b-fine-tuned"

# Basic loading without special parameters
try:
    # Try loading with minimum parameters
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,  # Add this to trust any custom code
        torch_dtype=torch.float16 if torch.cuda.is_available() else None
    )
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")
    print("\nTrying alternative loading method...")
    
    # If that fails, try with low_cpu_mem_usage
    try:
        model = AutoModelForCausalLM.from_pretrained(
            model_name,
            trust_remote_code=True,
            low_cpu_mem_usage=True,
            torch_dtype=torch.float16 if torch.cuda.is_available() else None
        )
        tokenizer = AutoTokenizer.from_pretrained(model_name)
        print("Model loaded successfully with alternative method!")
    except Exception as e:
        print(f"Alternative loading also failed: {e}")
# Out:
# Error loading model: Using `bitsandbytes` 4-bit quantization requires Accelerate: `pip install 'accelerate>=0.26.0'`
#
# Trying alternative loading method...
# Alternative loading also failed: Using `bitsandbytes` 4-bit quantization requires Accelerate: `pip install 'accelerate>=0.26.0'`

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig
import torch
import os

model_name = "fiendfrye/mental-status-classifier-lama-3.1-8b-fine-tuned"

# First, let's load just the config
config = AutoConfig.from_pretrained(model_name)

# Modify the config to remove quantization settings
if hasattr(config, "quantization_config"):
    delattr(config, "quantization_config")

# Now try loading with the modified config and other bypassing techniques
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    config=config,
    torch_dtype=torch.float16 if torch.cuda.is_available() else None,
    use_cache=True,
    device_map=None,
    revision="main",
    force_download=False,
    resume_download=True,
    local_files_only=False,
    trust_remote_code=True
)

tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Fetching 2 files:   0%|          | 0/2 [02:01<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      49 with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                   initargs=(lk,)) as ex:
# ---> 51     return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     618 if timeout is None:
# --> 619     yield _result_or_cancel(fs.pop())
#     620 else:
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     316 try:
# --> 317     return fut.result(timeout)
#     318 finally:
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     354 if timeout is None:
# --> 355     waiter.acquire()
#     356     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 15
#      12     delattr(config, "quantization_config")
#      14 # Now try loading with the modified config and other bypassing techniques
# ---> 15 model = AutoModelForCausalLM.from_pretrained(
#      16     model_name,
#      17     config=config,
#      18     torch_dtype=torch.float16 if torch.cuda.is_available() else None,
#      19     use_cache=True,
#      20     device_map=None,
#      21     revision="main",
#      22     force_download=False,
#      23     resume_download=True,
#      24     local_files_only=False,
#      25     trust_remote_code=True
#      26 )
#      28 tokenizer = AutoTokenizer.from_pretrained(model_name)
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:571, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569     if model_class.config_class == config.sub_configs.get("text_config", None):
#     570         config = config.get_text_config()
# --> 571     return model_class.from_pretrained(
#     572         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573     )
#     574 raise ValueError(
#     575     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     576     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     577 )
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/modeling_utils.py:279, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     277 old_dtype = torch.get_default_dtype()
#     278 try:
# --> 279     return func(*args, **kwargs)
#     280 finally:
#     281     torch.set_default_dtype(old_dtype)
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/modeling_utils.py:4260, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4250 if (
#    4251     gguf_file
#    4252     and device_map is not None
#    4253     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4254 ):
#    4255     raise RuntimeError(
#    4256         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4257         "loaded from GGUF files."
#    4258     )
# -> 4260 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4261     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4262     subfolder=subfolder,
#    4263     variant=variant,
#    4264     gguf_file=gguf_file,
#    4265     from_tf=from_tf,
#    4266     from_flax=from_flax,
#    4267     use_safetensors=use_safetensors,
#    4268     cache_dir=cache_dir,
#    4269     force_download=force_download,
#    4270     proxies=proxies,
#    4271     local_files_only=local_files_only,
#    4272     token=token,
#    4273     user_agent=user_agent,
#    4274     revision=revision,
#    4275     commit_hash=commit_hash,
#    4276 )
#    4278 is_sharded = sharded_metadata is not None
#    4279 is_quantized = hf_quantizer is not None
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/modeling_utils.py:1152, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash)
#    1150 sharded_metadata = None
#    1151 if is_sharded:
# -> 1152     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#    1153         pretrained_model_name_or_path,
#    1154         resolved_archive_file,
#    1155         cache_dir=cache_dir,
#    1156         force_download=force_download,
#    1157         proxies=proxies,
#    1158         local_files_only=local_files_only,
#    1159         token=token,
#    1160         user_agent=user_agent,
#    1161         revision=revision,
#    1162         subfolder=subfolder,
#    1163         _commit_hash=commit_hash,
#    1164     )
#    1165 else:
#    1166     checkpoint_files = [resolved_archive_file] if pretrained_model_name_or_path is not None else None
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/utils/hub.py:1115, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1111     return shard_filenames, sharded_metadata
#    1113 # At this stage pretrained_model_name_or_path is a model identifier on the Hub. Try to get everything from cache,
#    1114 # or download the files
# -> 1115 cached_filenames = cached_files(
#    1116     pretrained_model_name_or_path,
#    1117     shard_filenames,
#    1118     cache_dir=cache_dir,
#    1119     force_download=force_download,
#    1120     proxies=proxies,
#    1121     resume_download=resume_download,
#    1122     local_files_only=local_files_only,
#    1123     token=token,
#    1124     user_agent=user_agent,
#    1125     revision=revision,
#    1126     subfolder=subfolder,
#    1127     _commit_hash=_commit_hash,
#    1128 )
#    1130 return cached_filenames, sharded_metadata
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/transformers/utils/hub.py:439, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     424         hf_hub_download(
#     425             path_or_repo_id,
#     426             filenames[0],
#    (...)    436             local_files_only=local_files_only,
#     437         )
#     438     else:
# --> 439         snapshot_download(
#     440             path_or_repo_id,
#     441             allow_patterns=full_filenames,
#     442             repo_type=repo_type,
#     443             revision=revision,
#     444             cache_dir=cache_dir,
#     445             user_agent=user_agent,
#     446             force_download=force_download,
#     447             proxies=proxies,
#     448             resume_download=resume_download,
#     449             token=token,
#     450             local_files_only=local_files_only,
#     451         )
#     453 except Exception as e:
#     454     # We cannot recover from them
#     455     if isinstance(e, RepositoryNotFoundError) and not isinstance(e, GatedRepoError):
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/huggingface_hub/_snapshot_download.py:296, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     294         _inner_hf_hub_download(file)
#     295 else:
# --> 296     thread_map(
#     297         _inner_hf_hub_download,
#     298         filtered_repo_files,
#     299         desc=f"Fetching {len(filtered_repo_files)} files",
#     300         max_workers=max_workers,
#     301         # User can use its own tqdm class or the default one from `huggingface_hub.utils`
#     302         tqdm_class=tqdm_class or hf_tqdm,
#     303     )
#     305 if local_dir is not None:
#     306     return str(os.path.realpath(local_dir))
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)     66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/.pyenv/versions/dsai/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:49, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      46 lock_name = kwargs.pop("lock_name", "")
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
# ---> 49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
#      51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/concurrent/futures/thread.py:238, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     236 if wait:
#     237     for t in self._threads:
# --> 238         t.join()
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/threading.py:1149, in Thread.join(self, timeout)
#    1146     raise RuntimeError("cannot join current thread")
#    1148 if timeout is None:
# -> 1149     self._wait_for_tstate_lock()
#    1150 else:
#    1151     # the behavior of a negative timeout isn't documented, but
#    1152     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1153     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/threading.py:1169, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166     return
#    1168 try:
# -> 1169     if lock.acquire(block, timeout):
#    1170         lock.release()
#    1171         self._stop()
#
# KeyboardInterrupt:

# %%
from huggingface_hub import InferenceClient
from huggingface_hub import login

# Cell A5: Login to Hugging Face Hub
HF_TOKEN = HF_token  # Replace with your token
login(token=HF_TOKEN)

client = InferenceClient("fiendfrye/mental-status-classifier-lama-3.1-8b-fine-tuned")

prompt = "USER: I feel anxious all the time and can't sleep. \nASSISTANT:"
response = client.text_generation(prompt, max_new_tokens=100)

print(response)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/dsai2/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File ~/.pyenv/versions/dsai2/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://router.huggingface.co/hf-inference/models/fiendfrye/mental-status-classifier-lama-3.1-8b-fine-tuned
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[10], line 11
#       8 client = InferenceClient("fiendfrye/mental-status-classifier-lama-3.1-8b-fine-tuned")
#      10 prompt = "USER: I feel anxious all the time and can't sleep. \nASSISTANT:"
# ---> 11 response = client.text_generation(prompt, max_new_tokens=100)
#      13 print(response)
#
# File ~/.pyenv/versions/dsai2/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:2392, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2367         _set_unsupported_text_generation_kwargs(model, unused_params)
#    2368         return self.text_generation(  # type: ignore
#    2369             prompt=prompt,
#    2370             details=details,
#    (...)   2390             watermark=watermark,
#    2391         )
# -> 2392     raise_text_generation_error(e)
#    2394 # Parse output
#    2395 if stream:
#
# File ~/.pyenv/versions/dsai2/lib/python3.11/site-packages/huggingface_hub/inference/_common.py:402, in raise_text_generation_error(http_error)
#     400     error_type = payload.get("error_type")
#     401 except Exception:  # no payload
# --> 402     raise http_error
#     404 # If error_type => more information than `hf_raise_for_status`
#     405 if error_type is not None:
#
# File ~/.pyenv/versions/dsai2/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:2362, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2360 # Handle errors separately for more precise error messages
#    2361 try:
# -> 2362     bytes_output = self._inner_post(request_parameters, stream=stream)
#    2363 except HTTPError as e:
#    2364     match = MODEL_KWARGS_NOT_USED_REGEX.search(str(e))
#
# File ~/.pyenv/versions/dsai2/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:357, in InferenceClient._inner_post(self, request_parameters, stream)
#     354         raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     356 try:
# --> 357     hf_raise_for_status(response)
#     358     return response.iter_lines() if stream else response.content
#     359 except HTTPError as error:
#
# File ~/.pyenv/versions/dsai2/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     478     raise _format(HfHubHTTPError, message, response) from e
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://router.huggingface.co/hf-inference/models/fiendfrye/mental-status-classifier-lama-3.1-8b-fine-tuned
